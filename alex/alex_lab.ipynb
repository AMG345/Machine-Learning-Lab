# %%
import numpy as np
import pandas as pd

df=pd.read_csv(r"Orders.csv")
df.head(30)
# Out:
#     Row.ID                  Order.ID Order.Date Ship.Date       Ship.Mode  \
# 0    40098  CA-2014-AB10015140-41954   11/11/14  11/13/14     First Class
# 1    26341    IN-2014-JR162107-41675     2/5/14    2/7/14    Second Class
# 2    25330    IN-2014-CR127307-41929   10/17/14  10/18/14     First Class
# 3    13524   ES-2014-KM1637548-41667    1/28/14   1/30/14     First Class
# 4    47221   SG-2014-RH9495111-41948    11/5/14   11/6/14        Same Day
# 5    22732    IN-2014-JM156557-41818    6/28/14    7/1/14    Second Class
# 6    30570   IN-2012-TS2134092-41219    11/6/12   11/8/12     First Class
# 7    31192   IN-2013-MB1808592-41378    4/14/13   4/18/13  Standard Class
# 8    40099  CA-2014-AB10015140-41954   11/11/14  11/13/14     First Class
# 9    36258  CA-2012-AB10015140-40974     3/6/12    3/7/12     First Class
# 10   36259  CA-2012-AB10015140-40974     3/6/12    3/7/12     First Class
# 11   28879    ID-2013-AJ107801-41383    4/19/13   4/22/13     First Class
# ...

# %%
display(df)
# Out:
#        Row.ID                  Order.ID Order.Date Ship.Date       Ship.Mode  \
# 0       40098  CA-2014-AB10015140-41954   11/11/14  11/13/14     First Class
# 1       26341    IN-2014-JR162107-41675     2/5/14    2/7/14    Second Class
# 2       25330    IN-2014-CR127307-41929   10/17/14  10/18/14     First Class
# 3       13524   ES-2014-KM1637548-41667    1/28/14   1/30/14     First Class
# 4       47221   SG-2014-RH9495111-41948    11/5/14   11/6/14        Same Day
# ...       ...                       ...        ...       ...             ...
# 51285   29002   IN-2015-KE1642066-42174    6/19/15   6/19/15        Same Day
# 51286   34337  US-2014-ZD21925140-41765     5/6/14   5/10/14  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147    8/26/12   8/31/12    Second Class
# 51288    9596   MX-2013-RB1979518-41322    2/17/13   2/21/13  Standard Class
# 51289    6147   MX-2013-MC1810093-41416    5/22/13   5/26/13    Second Class
#
# ...

# %%
import re
import datetime

df['Order.Date']=pd.to_datetime(data['Order.Date'])
df['Ship.Date']=pd.to_datetime(data['Ship.Date'])

import matplotlib as plt
# %matplotlib inline

df['month'] = pd.to_datetime(data['Order.Date']).dt.strftime('%m')

# %%
df2=pd.read_csv(r"Returns.csv")
df2.head(40)
# Out:
#    Returned                  Order ID             Region
# 0       Yes  CA-2012-SA20830140-41210         Central US
# 1       Yes  IN-2012-PB19210127-41259       Eastern Asia
# 2       Yes  CA-2012-SC20095140-41174         Central US
# 3       Yes    IN-2015-JH158207-42140            Oceania
# 4       Yes    IN-2014-LC168857-41747            Oceania
# 5       Yes   ID-2013-AB1001527-41439       Eastern Asia
# 6       Yes   ES-2015-RA1994545-42218     Western Europe
# 7       Yes  CA-2014-TB21280140-41724         Central US
# 8       Yes  ES-2014-JF15295120-41924    Southern Europe
# 9       Yes   IN-2014-NM1844527-41800       Eastern Asia
# 10      Yes    IN-2015-GB145307-42260            Oceania
# 11      Yes    ES-2012-SC208458-41070     Western Europe
# 12      Yes  TU-2013-SF10200134-41417       Western Asia
# 13      Yes   ID-2015-RD1993092-42140            Oceania
# 14      Yes  CA-2014-TC21295140-41800        Southern US
# ...

# %%
df3 = pd.merge(df, df2, on='Order.ID', how='inner')
df3.head(50)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-82-97840b393cd7> in <module>
# ----> 1 df3 = pd.merge(df, df2, on='Order.ID', how='inner')
#       2 df3.head(50)
#
# ~/Anaconda_2.7/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      79         copy=copy,
#      80         indicator=indicator,
# ---> 81         validate=validate,
#      82     )
#      83     return op.get_result()
#
# ~/Anaconda_2.7/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     624             self.right_join_keys,
#     625             self.join_names,
# --> 626         ) = self._get_merge_keys()
# ...
